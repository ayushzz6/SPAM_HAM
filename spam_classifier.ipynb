# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn



df = pd.read_csv('spam.csv', encoding='latin-1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.shape
# Out:
# (5572, 5)

# %%
# data cleaning

df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
# droping the null values

df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1, inplace=True)
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# reanme 

df.rename(columns={'v1': 'target', 'v2': 'text'}, inplace=True)
df
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
#

# %%
#

# %%
#

# %%
# label encoder 
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['target'] = encoder.fit_transform(df['target'])
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
 # check for duplicates

df.duplicated().sum()
# Out:
# np.int64(403)

# %%
#delete duplicate 

df.drop_duplicates(inplace=True)
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
# EDA

# %%
# visualisation of target 

sns.countplot(x='target', data=df)
plt.show()

# pie chart

df['target'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# !pip install nltk # nlp library
import nltk
# Out:
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Ayush
# [nltk_data]     paul\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)
df['unique_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  unique_words
# 0                111            24
# 1                 29             8
# 2                155            37
# 3                 49            13
# ...

# %%
#no of sentences

df['num_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  unique_words  num_sentences
# 0                111            24              2
# 1                 29             8              2
# ...

# %%
df.columns
# Out:
# Index(['target', 'text', 'num_characters', 'unique_words', 'num_sentences'], dtype='object')

# %%
df[['num_characters', 'unique_words', 'num_sentences']].describe()
# Out:
#        num_characters  unique_words  num_sentences
# count     5169.000000   5169.000000    5169.000000
# mean        78.977945     18.455794       1.965564
# std         58.236293     13.324758       1.448541
# min          2.000000      1.000000       1.000000
# 25%         36.000000      9.000000       1.000000
# 50%         60.000000     15.000000       1.000000
# 75%        117.000000     26.000000       2.000000
# max        910.000000    220.000000      38.000000

# %%
# the ham mesaages only 

df[df['target'] == 0][['num_characters', 'unique_words', 'num_sentences']].describe()
# Out:
#        num_characters  unique_words  num_sentences
# count     4516.000000   4516.000000    4516.000000
# mean        70.459256     17.123782       1.820195
# std         56.358207     13.493970       1.383657
# min          2.000000      1.000000       1.000000
# 25%         34.000000      8.000000       1.000000
# 50%         52.000000     13.000000       1.000000
# 75%         90.000000     22.000000       2.000000
# max        910.000000    220.000000      38.000000

# %%
sns.histplot(x='unique_words', hue='target', data=df)
# Out:
# <Axes: xlabel='unique_words', ylabel='Count'>

# %%
#pair plot

sns.pairplot(df, hue='target')

# %%
#heatmap

sns.heatmap(df[['num_characters', 'unique_words', 'num_sentences']].corr(), annot=True)
# Out:
# <Axes: >

# %%
# data processing

# %%
#create a funct to lowercase the text , remove punctuations and stop words , tokenise the text

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Ayush
# [nltk_data]     paul\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = set(stopwords.words('english'))
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

# %%
import string

# %%
# transform function -> to lowercase , remove punctuations and stop words , tokenise the text

def transform(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    text = y[:]
    y.clear()
    for i in text:
        if i not in stopwords and i not in string.punctuation:
            y.append(i)
    text = y[:]
    y.clear()
    for i in text:
        y.append(stemmer.stem(i))
    return " ".join(y)

# %%
df['text'] = df['text'].apply(transform)
df
# Out:
#       target                                               text  \
# 0          0  go jurong point crazi avail bugi n great world...
# 1          0                              ok lar joke wif u oni
# 2          1  free entri 2 wkli comp win fa cup final tkt 21...
# 3          0                u dun say earli hor u c alreadi say
# 4          0               nah think goe usf live around though
# ...      ...                                                ...
# 5567       1  2nd time tri 2 contact u pound prize 2 claim e...
# 5568       0                              b go esplanad fr home
# 5569       0                                  piti mood suggest
# 5570       0  guy bitch act like interest buy someth els nex...
# 5571       0                                     rofl true name
#
#       num_characters  unique_words  num_sentences
# 0                111            24              2
# 1                 29             8              2
# ...

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
wc=WordCloud( width=800, height=600, max_words=100, background_color='white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['text'].str.cat(sep=' '))
ham_wc = wc.generate(df[df['target'] == 0]['text'].str.cat(sep=' '))

plt.figure(figsize=(15,8))
plt.imshow(spam_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

plt.figure(figsize=(15,8))
plt.imshow(ham_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
spam_corpus=[]

for i in df[df['target']==1]['text'].tolist():
    for j in i.split():
        spam_corpus.append(j)

ham_corpus=[]

for i in df[df['target']==0]['text'].tolist():
    for j in i.split():
        ham_corpus.append(j)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
len(ham_corpus)
# Out:
# 35404

# %%
# barplot of the count of top 20 spam and ham words and represent it in barplot

spam_corpus = nltk.FreqDist(spam_corpus)
ham_corpus = nltk.FreqDist(ham_corpus)
spam_corpus.most_common(20)
sns.barplot(x=[i[0] for i in spam_corpus.most_common(20)], y=[i[1] for i in spam_corpus.most_common(20)])
# Out:
# <Axes: >

# %%
sns.barplot(x=[i[0] for i in ham_corpus.most_common(20)], y=[i[1] for i in ham_corpus.most_common(20)])
# Out:
# <Axes: >

# %%
# model building

# %%
from sklearn.feature_extraction.text import CountVectorizer , TfidfVectorizer
cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
x= tfidf.fit_transform(df['text']).toarray()
y=df['target']

# %%
x.shape
# Out:
# (5169, 3000)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB , GaussianNB , BernoulliNB

# %%
gnb = GaussianNB()
mng = MultinomialNB()
bnb = BernoulliNB()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=96)

# %%
gnb.fit(x_train,y_train)
y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score , confusion_matrix , classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8481624758220503

# %%
mng.fit(x_train,y_train)
y_pred=mng.predict(x_test)
from sklearn.metrics import accuracy_score , confusion_matrix , classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9738878143133463

# %%
bnb.fit(x_train,y_train)    
y_pred=bnb.predict(x_test)
from sklearn.metrics import accuracy_score , confusion_matrix , classification_report        
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9796905222437138

# %%
import pickle

# %%
pickle.dump(tfidf , open('vectorizer.pkl' , 'wb'))
pickle.dump(mng , open('model.pkl' , 'wb'))
